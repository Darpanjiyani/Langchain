# %% [markdown]
# # LLM CALL

# %%
import os
from openai import OpenAI

# Initialize client
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

# Create chat completion
response = client.chat.completions.create(
    model="gpt-5-mini",  # updated model (gpt-3.5-turbo is deprecated)
    messages=[
        {"role": "user", "content": "Bro, tell me a fun fact"}
    ]
)

# Print output
print(response.choices[0].message.content)
# Out:
# Bro — fun fact: wombats poop in cubes. Their intestines shape the droppings into little blocks so they don’t roll away, making it easy to stack and mark territory; scientists say it’s due to varying elasticity in their gut. Want another weird one?

# %%
#from langchain_anthropic import ChatAnthropic
from langchain_openai import ChatOpenAI
import os
from load_dotenv import load_dotenv

load_dotenv() #This function will load everything which is saved in our .env file and will make them available
              # in the os.environ dictionary (env variables)

if os.environ.get("OPENAI_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("OPENAI_API_KEY not found")
# Out:
# Bro API KEY Variable exists

# %%
llm_openai = ChatOpenAI(model ='gpt-5-mini', temperature=0)
#llm_anthropic = ChatOpenAI(model ='claude-3-5-sonnet', temperature=0)

llm_openai.invoke("Bro, tell me a fun fact").content

# %%
from langchain.chat_models import init_chat_model

llm_openai = init_chat_model(model = "gpt-5-mini")

llm_openai.invoke("Hello, How are you?")
# Out:
# AIMessage(content="Hi — I'm an AI, so I don't have feelings, but I'm ready to help. What can I do for you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 35, 'prompt_tokens': 12, 'total_tokens': 47, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DPzs2EgyxNeGBlKIv6v5dRe6SZgdm', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d4b83-7d4f-7ad3-bf59-57d405678dc0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 35, 'total_tokens': 47, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
