# %%
#from langchain_anthropic import ChatAnthropic
from langchain_openai import ChatOpenAI
import os
from load_dotenv import load_dotenv

load_dotenv() #This function will load everything which is saved in our .env file and will make them available
              # in the os.environ dictionary (env variables)

if os.environ.get("OPENAI_API_KEY"):
    print("Bro, API KEY Variable Exists")
else: 
    raise ValueError("OPENAI_API_KEY not found")

from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm_openai = ChatOpenAI(model ='gpt-5-mini', temperature=0)
# Out:
# Bro, API KEY Variable Exists

# %% [markdown]
# # **CHAIN WITH CUSTOM RUNNABLE**

# %%
# TASK1 - Prompt

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant"),
    ("human", "{input}")
])

# %%
# TASK2 - LLM

llm_openai = ChatOpenAI(model ='gpt-5-mini', temperature=0)

# %%
# TASK3 - Str Parser

str_parser = StrOutputParser()

# %%
# TASK4 - Custom Runnable
from langchain_core.runnables import RunnableLambda

def dictionary_maker(text:str) -> dict:

    return {"text": text}

dictionary_maker_runnable = RunnableLambda(dictionary_maker)

# %%
# TASK5 - Template for post

prompt_post = ChatPromptTemplate.from_messages(
    messages=[
        ("system", "You are a social media post generator."),
        ("human", "Create a post for the following text for Linkedin: {text}")
    ]
)

# %%
# TASK6 - Generate the post

llm_openai = ChatOpenAI(model ='gpt-5-mini', temperature=0)

# %%
# TASK7 - Str Parser

str_parser = StrOutputParser()

# %%
# CHAIN

chain = prompt_template | llm_openai | str_parser | dictionary_maker_runnable | prompt_post | llm_openai | str_parser 

chain.invoke("What is the capital of France?")
# Out:
# 'Did you know? The capital of France is Paris.\n\nBeyond its iconic landmarks, Paris is a global hub for finance, fashion, tech, research and culture — a city where creativity and commerce meet. Whether you’re exploring market opportunities, building international partnerships, or simply seeking inspiration, Paris remains a key player on the world stage.\n\nHave you worked with teams or companies in Paris? What stood out to you? Share your experience below.  \n#Paris #France #InternationalBusiness #Culture #Networking'
